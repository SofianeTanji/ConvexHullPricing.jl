# %%
using Revise
using ConvexHullPricing
using Plots
using JLD2

# %%
dfBLM = load_object("C:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\results\\tables\\beBLMdf.jld2")
dfBPM = load_object("C:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\results\\tables\\beBPMdf.jld2")
dfDA = load_object("C:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\results\\tables\\beDAdf.jld2")
dfDowG = load_object("C:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\results\\tables\\beDowGdf.jld2")
dfPolyak = load_object("C:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\results\\tables\\bePolyakdf.jld2")

optimal = load_object("C:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\results\\tables\\beOptimalDF.jld2")

# %%
instance = 7

ValBLM = - dfBLM.fiterates[instance]
ValBPM = - dfBPM.fiterates[instance]
ValDA = - dfDA.fiterates[instance]
ValDowG = - dfDowG.fiterates[instance]
ValPolyak = - dfPolyak.fiterates[instance]
# Out:
# 31-element Vector{Float64}:
#  3.2805269142707477e9
#  3.2805087891547256e9
#  3.2804948945731483e9
#  3.280489505487019e9
#  3.28048117220856e9
#  3.280521517814168e9
#  3.280470221177351e9
#  3.2804700758171425e9
#  3.2804620695894394e9
#  3.280471630200689e9
#  ⋮
#  3.280452544986277e9
#  3.2804518588645444e9
#  3.280451732553272e9
#  3.280450657811862e9
#  3.280449586029597e9
#  3.2804524778130875e9
#  3.280451875424956e9
#  3.28044640418895e9
#  3.2804503399986453e9

# %%
# hline([- optimal.fiterates[instance][end]], label = "Optimal value")
plot(ValBLM[1:100], label = "Bundle Level Method", linewidth = 1.5)
plot!(ValBPM[1:100], label = "Bundle Proximal Method", linewidth = 1.5)
plot!(ValDowG[1:100], label = "DoWG", linewidth = 1.5)
plot!(ValDA[1:100], label = "D-Adaptation", linewidth = 1.5)
plot!(ValPolyak, label = "Polyak", linewidth = 1.5)
plot!(size = (1500, 900))
