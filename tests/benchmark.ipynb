# %%
using Revise
using ConvexHullPricing
using DataFrames
using Plots
using JLD2
using ProgressBars

# %%
# Rewrite loaders
# FGM est censé converger. Ou est le pb. Tradeoff Lipshitz FGM. Linesearch sur le L. Longueur de pas trop grande puis la diminuer petit à petit avec un linesearch
# Vrais restarts
FGM = load_object("C:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\results\\figures\\beFGM.jld2")
# Out:
# 8-element Vector{Any}:
#  [[-3.1510002077969446e9, -3.1510002079995694e9, -3.1510002082528496e9, -3.151000208556784e9, -3.1510002089113717e9, -3.1510002093166122e9, -3.151000209772502e9, -3.151000210277065e9, -3.1510002108340044e9, -3.1510002114415436e9  …  -3.1510003297210283e9, -3.1510003332611265e9, -3.1510003368516464e9, -3.151000340492579e9, -3.1510003441803455e9, -3.151000347920139e9, -3.1510003517175007e9, -3.1510003555583735e9, -3.1510003594526606e9, -3.1510003633957973e9], [3.918133, 7.8262029, 11.7314025, 15.6584817, 19.6200678, 23.5291032, 27.4179196, 31.297373200000003, 35.150665800000006, 38.95361640000001  …  264.2986920000001, 268.34312830000005, 272.3656303, 276.4116942, 280.698729, 284.8589902, 289.02903399999997, 293.13314049999997, 297.2073038, 301.4182265]]
# ...

# %%
plot(FGM[1][2], FGM[1][1], xlabel = "Time", ylabel = "Remaining uplifts", label = "FGM")

# %%
plot_instance(8)
savefig("test2")
# Out:
# UndefVarError: `plot_instance` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\Sofiane\Desktop\ConvexHullPricing\tests\benchmark.ipynb:1

# %%
plot(bigBLM[I][2][150:end], bigBLM[I][1][150:end], xlabel = "Time in seconds", ylabel = "Remaining uplifts", label = "BLM")
plot!(bigBPM[I][2][150:end], bigBPM[I][1][150:end], label = "BPM")
plot!(bigDA[I][2][150:end], bigDA[I][1][150:end], label = "DA")
plot!(bigDowG[I][2][150:end], bigDowG[I][1][150:end], label = "DowG")
plot!(bigePol[I][2][150:end], bigePol[I][1][150:end], label = "ePol")
plot!(bigGD[I][2][150:end], bigGD[I][1][150:end], label = "SubG-M")
plot!(bigCG[I][2][150:end], bigCG[I][1][150:end], label = "CG")
savefig("test3")
# Out:
# "c:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\tests\\test3.png"

# %%
# Instance I
function plot_instance(I)
    # plot(bigBLM[I][2], bigBLM[I][1], xlabel = "Time in seconds", ylabel = "Remaining uplifts", label = "BLM", dpi = 500)
    plot(bigBPM[I][2], bigBPM[I][1], label = "BPM")
    plot!(bigDA[I][2], bigDA[I][1], label = "DA")
    plot!(bigDowG[I][2], bigDowG[I][1], label = "DowG")
    plot!(bigePol[I][2], bigePol[I][1], label = "ePol")
    plot!(bigGD[I][2], bigGD[I][1], label = "SubG-M")
    # plot(bigCG[I][2], bigCG[I][1], label = "CG")
end
# Out:
# plot_instance (generic function with 1 method)

# %%
list_of_plots =  [plot_instance(I) for I in 1:28]
# Out:
# 28-element Vector{Plots.Plot{Plots.GRBackend}}:
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  ⋮
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}
#  Plot{Plots.GRBackend() n=6}

# %%
display(list_of_plots[1])
