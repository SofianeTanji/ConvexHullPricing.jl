# %%
@info "Imports ..."
using Revise
using ConvexHullPricing
using DataFrames
using Plots
using JLD2
using ProgressBars
const UT = ConvexHullPricing.Utilitaries
const OPT = ConvexHullPricing.Optimizer

# %% [markdown]
# # PLOT AGGREGATIONS

# %% [markdown]
# ## BE Agregation

# %%
BE1BLMtime, BE1BLMval = load_object("december\\belgian1BLM")
BE2BLMtime, BE2BLMval = load_object("december\\belgian2BLM")
BE3BLMtime, BE3BLMval = load_object("december\\belgian3BLM")
BE4BLMtime, BE4BLMval = load_object("december\\belgian4BLM")
BE5BLMtime, BE5BLMval = load_object("december\\belgian5BLM")
BE6BLMtime, BE6BLMval = load_object("december\\belgian6BLM")
BE7BLMtime, BE7BLMval = load_object("december\\belgian7BLM")
BE8BLMtime, BE8BLMval = load_object("december\\belgian8BLM")
cutBLM = minimum([#length(BE1BLMval),
 length(BE2BLMval), length(BE3BLMval), length(BE4BLMval), length(BE5BLMval), length(BE6BLMval), length(BE7BLMval), length(BE8BLMval)])
selectBLM = argmin([#length(BE1BLMval),
 length(BE2BLMval), length(BE3BLMval), length(BE4BLMval), length(BE5BLMval), length(BE6BLMval), length(BE7BLMval), length(BE8BLMval)])
matrixBLM = [#BE1BLMval[1:cut],
 BE2BLMval[1:cut], BE3BLMval[1:cut], BE4BLMval[1:cut], BE5BLMval[1:cut], BE6BLMval[1:cut], BE7BLMval[1:cut], BE8BLMval[1:cut]]
aggregateBLM = mean(matrixBLM)

# %%
BE1BPLMtime, BE1BPLMval = load_object("december\\belgian1BPLM")
BE2BPLMtime, BE2BPLMval = load_object("december\\belgian2BPLM")
BE3BPLMtime, BE3BPLMval = load_object("december\\belgian3BPLM")
BE4BPLMtime, BE4BPLMval = load_object("december\\belgian4BPLM")
BE5BPLMtime, BE5BPLMval = load_object("december\\belgian5BPLM")
BE6BPLMtime, BE6BPLMval = load_object("december\\belgian6BPLM")
BE7BPLMtime, BE7BPLMval = load_object("december\\belgian7BPLM")
BE8BPLMtime, BE8BPLMval = load_object("december\\belgian8BPLM")
cutBPLM = minimum([
    #length(BE1BPLMval),
    length(BE2BPLMval),
    length(BE3BPLMval),
    length(BE4BPLMval),
    length(BE5BPLMval),
    length(BE6BPLMval),
    length(BE7BPLMval),
    length(BE8BPLMval)])
selectBPLM = argmin([
    #length(BE1BPLMval),
    length(BE2BPLMval),
    length(BE3BPLMval),
    length(BE4BPLMval),
    length(BE5BPLMval),
    length(BE6BPLMval),
    length(BE7BPLMval),
    length(BE8BPLMval)])
matrixBPLM = [
    #BE1BPLMval[1:cutBPLM],
    BE2BPLMval[1:cutBPLM],
    BE3BPLMval[1:cutBPLM],
    BE4BPLMval[1:cutBPLM],
    BE5BPLMval[1:cutBPLM],
    BE6BPLMval[1:cutBPLM],
    BE7BPLMval[1:cutBPLM],
    BE8BPLMval[1:cutBPLM]]
aggregateBPLM = mean(matrixBPLM)

# %%
BE1DAtime, BE1DAval = load_object("december\\belgian1DA")
BE2DAtime, BE2DAval = load_object("december\\belgian2DA")
BE3DAtime, BE3DAval = load_object("december\\belgian3DA")
BE4DAtime, BE4DAval = load_object("december\\belgian4DA")
BE5DAtime, BE5DAval = load_object("december\\belgian5DA")
BE6DAtime, BE6DAval = load_object("december\\belgian6DA")
BE7DAtime, BE7DAval = load_object("december\\belgian7DA")
BE8DAtime, BE8DAval = load_object("december\\belgian8DA")
cutDA = minimum([
    #length(BE1DAval),
    length(BE2DAval),
    length(BE3DAval),
    length(BE4DAval),
    length(BE5DAval),
    length(BE6DAval),
    length(BE7DAval),
    length(BE8DAval)])
selectDA = argmin([
    #length(BE1DAval),
    length(BE2DAval),
    length(BE3DAval),
    length(BE4DAval),
    length(BE5DAval),
    length(BE6DAval),
    length(BE7DAval),
    length(BE8DAval)])
matrixDA = [
    #BE1DAval[1:cutDA],
    BE2DAval[1:cutDA],
    BE3DAval[1:cutDA],
    BE4DAval[1:cutDA],
    BE5DAval[1:cutDA],
    BE6DAval[1:cutDA],
    BE7DAval[1:cutDA],
    BE8DAval[1:cutDA]]
aggregateDA = mean(matrixDA)

# %%
BE1DOWGtime, BE1DOWGval = load_object("december\\belgian1DOWG")
BE2DOWGtime, BE2DOWGval = load_object("december\\belgian2DOWG")
BE3DOWGtime, BE3DOWGval = load_object("december\\belgian3DOWG")
BE4DOWGtime, BE4DOWGval = load_object("december\\belgian4DOWG")
BE5DOWGtime, BE5DOWGval = load_object("december\\belgian5DOWG")
BE6DOWGtime, BE6DOWGval = load_object("december\\belgian6DOWG")
BE7DOWGtime, BE7DOWGval = load_object("december\\belgian7DOWG")
BE8DOWGtime, BE8DOWGval = load_object("december\\belgian8DOWG")
cutDOWG = minimum([
    #length(BE1DOWGval),
    length(BE2DOWGval),
    length(BE3DOWGval),
    length(BE4DOWGval),
    length(BE5DOWGval),
    length(BE6DOWGval),
    length(BE7DOWGval),
    length(BE8DOWGval)])
selectDOWG = argmin([
    #length(BE1DOWGval),
    length(BE2DOWGval),
    length(BE3DOWGval),
    length(BE4DOWGval),
    length(BE5DOWGval),
    length(BE6DOWGval),
    length(BE7DOWGval),
    length(BE8DOWGval)])
matrixDOWG = [
    #BE1DOWGval[1:cutDOWG],
    BE2DOWGval[1:cutDOWG],
    BE3DOWGval[1:cutDOWG],
    BE4DOWGval[1:cutDOWG],
    BE5DOWGval[1:cutDOWG],
    BE6DOWGval[1:cutDOWG],
    BE7DOWGval[1:cutDOWG],
    BE8DOWGval[1:cutDOWG]]
aggregateDOWG = mean(matrixDOWG)

# %%
BE1ESTPOLtime, BE1ESTPOLval = load_object("december\\belgian1ESTPOL")
BE2ESTPOLtime, BE2ESTPOLval = load_object("december\\belgian2ESTPOL")
BE3ESTPOLtime, BE3ESTPOLval = load_object("december\\belgian3ESTPOL")
BE4ESTPOLtime, BE4ESTPOLval = load_object("december\\belgian4ESTPOL")
BE5ESTPOLtime, BE5ESTPOLval = load_object("december\\belgian5ESTPOL")
BE6ESTPOLtime, BE6ESTPOLval = load_object("december\\belgian6ESTPOL")
BE7ESTPOLtime, BE7ESTPOLval = load_object("december\\belgian7ESTPOL")
BE8ESTPOLtime, BE8ESTPOLval = load_object("december\\belgian8ESTPOL")
cutESTPOL = minimum([
    #length(BE1ESTPOLval),
    length(BE2ESTPOLval),
    length(BE3ESTPOLval),
    length(BE4ESTPOLval),
    length(BE5ESTPOLval),
    length(BE6ESTPOLval),
    length(BE7ESTPOLval),
    length(BE8ESTPOLval)])
selectESTPOL = argmin([
    #length(BE1ESTPOLval),
    length(BE2ESTPOLval),
    length(BE3ESTPOLval),
    length(BE4ESTPOLval),
    length(BE5ESTPOLval),
    length(BE6ESTPOLval),
    length(BE7ESTPOLval),
    length(BE8ESTPOLval)])
matrixESTPOL = [
    #BE1ESTPOLval[1:cutESTPOL],
    BE2ESTPOLval[1:cutESTPOL],
    BE3ESTPOLval[1:cutESTPOL],
    BE4ESTPOLval[1:cutESTPOL],
    BE5ESTPOLval[1:cutESTPOL],
    BE6ESTPOLval[1:cutESTPOL],
    BE7ESTPOLval[1:cutESTPOL],
    BE8ESTPOLval[1:cutESTPOL]]
aggregateESTPOL = mean(matrixESTPOL)

# %%
BE1SUBGtime, BE1SUBGval = load_object("december\\belgian1SUBG")
BE2SUBGtime, BE2SUBGval = load_object("december\\belgian2SUBG")
BE3SUBGtime, BE3SUBGval = load_object("december\\belgian3SUBG")
BE4SUBGtime, BE4SUBGval = load_object("december\\belgian4SUBG")
BE5SUBGtime, BE5SUBGval = load_object("december\\belgian5SUBG")
BE6SUBGtime, BE6SUBGval = load_object("december\\belgian6SUBG")
BE7SUBGtime, BE7SUBGval = load_object("december\\belgian7SUBG")
BE8SUBGtime, BE8SUBGval = load_object("december\\belgian8SUBG")
cutSUBG = minimum([
    #length(BE1SUBGval),
    length(BE2SUBGval),
    length(BE3SUBGval),
    length(BE4SUBGval),
    length(BE5SUBGval),
    length(BE6SUBGval),
    length(BE7SUBGval),
    length(BE8SUBGval)])
selectSUBG = argmin([
    #length(BE1SUBGval),
    length(BE2SUBGval),
    length(BE3SUBGval),
    length(BE4SUBGval),
    length(BE5SUBGval),
    length(BE6SUBGval),
    length(BE7SUBGval),
    length(BE8SUBGval)])
matrixSUBG = [
    #BE1SUBGval[1:cutSUBG],
    BE2SUBGval[1:cutSUBG],
    BE3SUBGval[1:cutSUBG],
    BE4SUBGval[1:cutSUBG],
    BE5SUBGval[1:cutSUBG],
    BE6SUBGval[1:cutSUBG],
    BE7SUBGval[1:cutSUBG],
    BE8SUBGval[1:cutSUBG]]
aggregateSUBG = mean(matrixSUBG)

# %%
plot(xlabel = "Time in seconds", ylabel = "Function value gap", title = "Belgian dataset", ylims = (0,3e4))
plot!(BE7BLMtime[2:end], aggregateBLM, label = "BLM")
plot!(BE7BPLMtime[2:end], aggregateBPLM, label = "BPLM")
plot!(BE7DAtime[2:end], aggregateDA, label = "DA")
plot!(BE7DOWGtime[2:end], aggregateDOWG, label = "DOWG")
plot!(BE7ESTPOLtime[2:end], aggregateESTPOL, label = "ESTPOL")
plot!(BE3SUBGtime[2:end], aggregateSUBG, label = "SUBG")
savefig("december\\AggregatePlotBE")

# %% [markdown]
# ## CA Agreg

# %%
CA01BLMtime, CA01BLMval = load_object("december\\californian1BLM")
CA02BLMtime, CA02BLMval = load_object("december\\californian2BLM")
CA03BLMtime, CA03BLMval = load_object("december\\californian3BLM")
CA04BLMtime, CA04BLMval = load_object("december\\californian4BLM")
CA05BLMtime, CA05BLMval = load_object("december\\californian5BLM")
CA06BLMtime, CA06BLMval = load_object("december\\californian6BLM")
CA07BLMtime, CA07BLMval = load_object("december\\californian7BLM")
CA08BLMtime, CA08BLMval = load_object("december\\californian8BLM")
CA13BLMtime, CA13BLMval = load_object("december\\californian13BLM")
CA14BLMtime, CA14BLMval = load_object("december\\californian14BLM")
CA15BLMtime, CA15BLMval = load_object("december\\californian15BLM")
CA16BLMtime, CA16BLMval = load_object("december\\californian16BLM")
CA17BLMtime, CA17BLMval = load_object("december\\californian17BLM")
CA18BLMtime, CA18BLMval = load_object("december\\californian18BLM")
CA19BLMtime, CA19BLMval = load_object("december\\californian19BLM")
CA20BLMtime, CA20BLMval = load_object("december\\californian20BLM")
cutCABLM = minimum([
    #length(CA01BLMval),
    length(CA02BLMval),
    length(CA03BLMval),
    length(CA04BLMval),
    length(CA05BLMval),
    length(CA06BLMval),
    length(CA07BLMval),
    length(CA08BLMval),
    length(CA13BLMval),
    #length(CA14BLMval),
    #length(CA15BLMval),
    #length(CA16BLMval),
    #length(CA17BLMval),
    #length(CA18BLMval),
    #length(CA19BLMval),
    #length(CA20BLMval)
    ])
selectCABLM = argmin([
    #length(CA01BLMval),
    length(CA02BLMval),
    length(CA03BLMval),
    length(CA04BLMval),
    length(CA05BLMval),
    length(CA06BLMval),
    length(CA07BLMval),
    length(CA08BLMval),
    length(CA13BLMval),
    #length(CA14BLMval),
    #length(CA15BLMval),
    #length(CA16BLMval),
    #length(CA17BLMval),
    #length(CA18BLMval),
    #length(CA19BLMval),
    #length(CA20BLMval)
    ])
matrixCABLM = [
    #CA01BLMval[1:cutCABLM],
    CA02BLMval[1:cutCABLM],
    CA03BLMval[1:cutCABLM],
    CA04BLMval[1:cutCABLM],
    CA05BLMval[1:cutCABLM],
    CA06BLMval[1:cutCABLM],
    CA07BLMval[1:cutCABLM],
    CA08BLMval[1:cutCABLM],
    CA13BLMval[1:cutCABLM],
    #CA14BLMval[1:cutCABLM],
    #CA15BLMval[1:cutCABLM],
    #CA16BLMval[1:cutCABLM],
    #CA17BLMval[1:cutCABLM],
    #CA18BLMval[1:cutCABLM],
    #CA19BLMval[1:cutCABLM],
    #CA20BLMval[1:cutCABLM]
    ]
aggregateCABLM = mean(matrixCABLM)

# %%
CA01BPLMtime, CA01BPLMval = load_object("december\\californian1BPLM")
CA02BPLMtime, CA02BPLMval = load_object("december\\californian2BPLM")
CA03BPLMtime, CA03BPLMval = load_object("december\\californian3BPLM")
CA04BPLMtime, CA04BPLMval = load_object("december\\californian4BPLM")
CA05BPLMtime, CA05BPLMval = load_object("december\\californian5BPLM")
CA06BPLMtime, CA06BPLMval = load_object("december\\californian6BPLM")
CA07BPLMtime, CA07BPLMval = load_object("december\\californian7BPLM")
CA08BPLMtime, CA08BPLMval = load_object("december\\californian8BPLM")
CA13BPLMtime, CA13BPLMval = load_object("december\\californian13BPLM")
CA14BPLMtime, CA14BPLMval = load_object("december\\californian14BPLM")
CA15BPLMtime, CA15BPLMval = load_object("december\\californian15BPLM")
CA16BPLMtime, CA16BPLMval = load_object("december\\californian16BPLM")
CA17BPLMtime, CA17BPLMval = load_object("december\\californian17BPLM")
CA18BPLMtime, CA18BPLMval = load_object("december\\californian18BPLM")
CA19BPLMtime, CA19BPLMval = load_object("december\\californian19BPLM")
CA20BPLMtime, CA20BPLMval = load_object("december\\californian20BPLM")
cutCABPLM = minimum([
    #length(CA01BPLMval),
    length(CA02BPLMval),
    length(CA03BPLMval),
    length(CA04BPLMval),
    length(CA05BPLMval),
    length(CA06BPLMval),
    length(CA07BPLMval),
    length(CA08BPLMval),
    length(CA13BPLMval),
    length(CA14BPLMval),
    length(CA15BPLMval),
    length(CA16BPLMval),
    length(CA17BPLMval),
    length(CA18BPLMval),
    length(CA19BPLMval),
    length(CA20BPLMval)])
selectCABPLM = argmin([
    #length(CA01BPLMval),
    length(CA02BPLMval),
    length(CA03BPLMval),
    length(CA04BPLMval),
    length(CA05BPLMval),
    length(CA06BPLMval),
    length(CA07BPLMval),
    length(CA08BPLMval),
    length(CA13BPLMval),
    length(CA14BPLMval),
    length(CA15BPLMval),
    length(CA16BPLMval),
    length(CA17BPLMval),
    length(CA18BPLMval),
    length(CA19BPLMval),
    length(CA20BPLMval)])
matrixCABPLM = [
    #CA01BPLMval[1:cutCABPLM],
    CA02BPLMval[1:cutCABPLM],
    CA03BPLMval[1:cutCABPLM],
    CA04BPLMval[1:cutCABPLM],
    CA05BPLMval[1:cutCABPLM],
    CA06BPLMval[1:cutCABPLM],
    CA07BPLMval[1:cutCABPLM],
    CA08BPLMval[1:cutCABPLM],
    CA13BPLMval[1:cutCABPLM],
    CA14BPLMval[1:cutCABPLM],
    CA15BPLMval[1:cutCABPLM],
    CA16BPLMval[1:cutCABPLM],
    CA17BPLMval[1:cutCABPLM],
    CA18BPLMval[1:cutCABPLM],
    CA19BPLMval[1:cutCABPLM],
    CA20BPLMval[1:cutCABPLM]]
aggregateCABPLM = mean(matrixCABPLM)

# %%
CA01DAtime, CA01DAval = load_object("december\\californian1DA")
CA02DAtime, CA02DAval = load_object("december\\californian2DA")
CA03DAtime, CA03DAval = load_object("december\\californian3DA")
CA04DAtime, CA04DAval = load_object("december\\californian4DA")
CA05DAtime, CA05DAval = load_object("december\\californian5DA")
CA06DAtime, CA06DAval = load_object("december\\californian6DA")
CA07DAtime, CA07DAval = load_object("december\\californian7DA")
CA08DAtime, CA08DAval = load_object("december\\californian8DA")
CA13DAtime, CA13DAval = load_object("december\\californian13DA")
CA14DAtime, CA14DAval = load_object("december\\californian14DA")
CA15DAtime, CA15DAval = load_object("december\\californian15DA")
CA16DAtime, CA16DAval = load_object("december\\californian16DA")
CA17DAtime, CA17DAval = load_object("december\\californian17DA")
CA18DAtime, CA18DAval = load_object("december\\californian18DA")
CA19DAtime, CA19DAval = load_object("december\\californian19DA")
CA20DAtime, CA20DAval = load_object("december\\californian20DA")
cutCADA = minimum([
    #length(CA01DAval),
    length(CA02DAval),
    length(CA03DAval),
    length(CA04DAval),
    length(CA05DAval),
    length(CA06DAval),
    length(CA07DAval),
    length(CA08DAval),
    length(CA13DAval),
    length(CA14DAval),
    length(CA15DAval),
    length(CA16DAval),
    length(CA17DAval),
    length(CA18DAval),
    length(CA19DAval),
    length(CA20DAval)])
selectCADA = argmin([
    #length(CA01DAval),
    length(CA02DAval),
    length(CA03DAval),
    length(CA04DAval),
    length(CA05DAval),
    length(CA06DAval),
    length(CA07DAval),
    length(CA08DAval),
    length(CA13DAval),
    length(CA14DAval),
    length(CA15DAval),
    length(CA16DAval),
    length(CA17DAval),
    length(CA18DAval),
    length(CA19DAval),
    length(CA20DAval)])
matrixCADA = [
    #CA01DAval[1:cutCADA],
    CA02DAval[1:cutCADA],
    CA03DAval[1:cutCADA],
    CA04DAval[1:cutCADA],
    CA05DAval[1:cutCADA],
    CA06DAval[1:cutCADA],
    CA07DAval[1:cutCADA],
    CA08DAval[1:cutCADA],
    CA13DAval[1:cutCADA],
    CA14DAval[1:cutCADA],
    CA15DAval[1:cutCADA],
    CA16DAval[1:cutCADA],
    CA17DAval[1:cutCADA],
    CA18DAval[1:cutCADA],
    CA19DAval[1:cutCADA],
    CA20DAval[1:cutCADA]]
aggregateCADA = mean(matrixCADA)

# %%
CA01DOWGtime, CA01DOWGval = load_object("december\\californian1DOWG")
CA02DOWGtime, CA02DOWGval = load_object("december\\californian2DOWG")
CA03DOWGtime, CA03DOWGval = load_object("december\\californian3DOWG")
CA04DOWGtime, CA04DOWGval = load_object("december\\californian4DOWG")
CA05DOWGtime, CA05DOWGval = load_object("december\\californian5DOWG")
CA06DOWGtime, CA06DOWGval = load_object("december\\californian6DOWG")
CA07DOWGtime, CA07DOWGval = load_object("december\\californian7DOWG")
CA08DOWGtime, CA08DOWGval = load_object("december\\californian8DOWG")
CA13DOWGtime, CA13DOWGval = load_object("december\\californian13DOWG")
CA14DOWGtime, CA14DOWGval = load_object("december\\californian14DOWG")
CA15DOWGtime, CA15DOWGval = load_object("december\\californian15DOWG")
CA16DOWGtime, CA16DOWGval = load_object("december\\californian16DOWG")
CA17DOWGtime, CA17DOWGval = load_object("december\\californian17DOWG")
CA18DOWGtime, CA18DOWGval = load_object("december\\californian18DOWG")
CA19DOWGtime, CA19DOWGval = load_object("december\\californian19DOWG")
CA20DOWGtime, CA20DOWGval = load_object("december\\californian20DOWG")
cutCADOWG = minimum([
    #length(CA01DOWGval),
    length(CA02DOWGval),
    length(CA03DOWGval),
    length(CA04DOWGval),
    length(CA05DOWGval),
    length(CA06DOWGval),
    length(CA07DOWGval),
    length(CA08DOWGval),
    length(CA13DOWGval),
    length(CA14DOWGval),
    length(CA15DOWGval),
    length(CA16DOWGval),
    length(CA17DOWGval),
    length(CA18DOWGval),
    length(CA19DOWGval),
    length(CA20DOWGval)])
selectCADOWG = argmin([
    #length(CA01DOWGval),
    length(CA02DOWGval),
    length(CA03DOWGval),
    length(CA04DOWGval),
    length(CA05DOWGval),
    length(CA06DOWGval),
    length(CA07DOWGval),
    length(CA08DOWGval),
    length(CA13DOWGval),
    length(CA14DOWGval),
    length(CA15DOWGval),
    length(CA16DOWGval),
    length(CA17DOWGval),
    length(CA18DOWGval),
    length(CA19DOWGval),
    length(CA20DOWGval)])
matrixCADOWG = [
    #CA01DOWGval[1:cutCADOWG],
    CA02DOWGval[1:cutCADOWG],
    CA03DOWGval[1:cutCADOWG],
    CA04DOWGval[1:cutCADOWG],
    CA05DOWGval[1:cutCADOWG],
    CA06DOWGval[1:cutCADOWG],
    CA07DOWGval[1:cutCADOWG],
    CA08DOWGval[1:cutCADOWG],
    CA13DOWGval[1:cutCADOWG],
    CA14DOWGval[1:cutCADOWG],
    CA15DOWGval[1:cutCADOWG],
    CA16DOWGval[1:cutCADOWG],
    CA17DOWGval[1:cutCADOWG],
    CA18DOWGval[1:cutCADOWG],
    CA19DOWGval[1:cutCADOWG],
    CA20DOWGval[1:cutCADOWG]]
aggregateCADOWG = mean(matrixCADOWG)

# %%
CA01ESTPOLtime, CA01ESTPOLval = load_object("december\\californian1ESTPOL")
CA02ESTPOLtime, CA02ESTPOLval = load_object("december\\californian2ESTPOL")
CA03ESTPOLtime, CA03ESTPOLval = load_object("december\\californian3ESTPOL")
CA04ESTPOLtime, CA04ESTPOLval = load_object("december\\californian4ESTPOL")
CA05ESTPOLtime, CA05ESTPOLval = load_object("december\\californian5ESTPOL")
CA06ESTPOLtime, CA06ESTPOLval = load_object("december\\californian6ESTPOL")
CA07ESTPOLtime, CA07ESTPOLval = load_object("december\\californian7ESTPOL")
CA08ESTPOLtime, CA08ESTPOLval = load_object("december\\californian8ESTPOL")
CA13ESTPOLtime, CA13ESTPOLval = load_object("december\\californian13ESTPOL")
CA14ESTPOLtime, CA14ESTPOLval = load_object("december\\californian14ESTPOL")
CA15ESTPOLtime, CA15ESTPOLval = load_object("december\\californian15ESTPOL")
CA16ESTPOLtime, CA16ESTPOLval = load_object("december\\californian16ESTPOL")
CA17ESTPOLtime, CA17ESTPOLval = load_object("december\\californian17ESTPOL")
CA18ESTPOLtime, CA18ESTPOLval = load_object("december\\californian18ESTPOL")
CA19ESTPOLtime, CA19ESTPOLval = load_object("december\\californian19ESTPOL")
CA20ESTPOLtime, CA20ESTPOLval = load_object("december\\californian20ESTPOL")
cutCAESTPOL = minimum([
    #length(CA01ESTPOLval),
    length(CA02ESTPOLval),
    length(CA03ESTPOLval),
    length(CA04ESTPOLval),
    length(CA05ESTPOLval),
    length(CA06ESTPOLval),
    length(CA07ESTPOLval),
    length(CA08ESTPOLval),
    length(CA13ESTPOLval),
    length(CA14ESTPOLval),
    length(CA15ESTPOLval),
    length(CA16ESTPOLval),
    length(CA17ESTPOLval),
    length(CA18ESTPOLval),
    length(CA19ESTPOLval),
    length(CA20ESTPOLval)])
selectCAESTPOL = argmin([
    #length(CA01ESTPOLval),
    length(CA02ESTPOLval),
    length(CA03ESTPOLval),
    length(CA04ESTPOLval),
    length(CA05ESTPOLval),
    length(CA06ESTPOLval),
    length(CA07ESTPOLval),
    length(CA08ESTPOLval),
    length(CA13ESTPOLval),
    length(CA14ESTPOLval),
    length(CA15ESTPOLval),
    length(CA16ESTPOLval),
    length(CA17ESTPOLval),
    length(CA18ESTPOLval),
    length(CA19ESTPOLval),
    length(CA20ESTPOLval)])
matrixCAESTPOL = [
    #CA01ESTPOLval[1:cutCAESTPOL],
    CA02ESTPOLval[1:cutCAESTPOL],
    CA03ESTPOLval[1:cutCAESTPOL],
    CA04ESTPOLval[1:cutCAESTPOL],
    CA05ESTPOLval[1:cutCAESTPOL],
    CA06ESTPOLval[1:cutCAESTPOL],
    CA07ESTPOLval[1:cutCAESTPOL],
    CA08ESTPOLval[1:cutCAESTPOL],
    CA13ESTPOLval[1:cutCAESTPOL],
    CA14ESTPOLval[1:cutCAESTPOL],
    CA15ESTPOLval[1:cutCAESTPOL],
    CA16ESTPOLval[1:cutCAESTPOL],
    CA17ESTPOLval[1:cutCAESTPOL],
    CA18ESTPOLval[1:cutCAESTPOL],
    CA19ESTPOLval[1:cutCAESTPOL],
    CA20ESTPOLval[1:cutCAESTPOL]]
aggregateCAESTPOL = mean(matrixCAESTPOL)

# %%
CA01SUBGtime, CA01SUBGval = load_object("december\\californian1SUBG")
CA02SUBGtime, CA02SUBGval = load_object("december\\californian2SUBG")
CA03SUBGtime, CA03SUBGval = load_object("december\\californian3SUBG")
CA04SUBGtime, CA04SUBGval = load_object("december\\californian4SUBG")
CA05SUBGtime, CA05SUBGval = load_object("december\\californian5SUBG")
CA06SUBGtime, CA06SUBGval = load_object("december\\californian6SUBG")
CA07SUBGtime, CA07SUBGval = load_object("december\\californian7SUBG")
CA08SUBGtime, CA08SUBGval = load_object("december\\californian8SUBG")
CA13SUBGtime, CA13SUBGval = load_object("december\\californian13SUBG")
CA14SUBGtime, CA14SUBGval = load_object("december\\californian14SUBG")
CA15SUBGtime, CA15SUBGval = load_object("december\\californian15SUBG")
CA16SUBGtime, CA16SUBGval = load_object("december\\californian16SUBG")
CA17SUBGtime, CA17SUBGval = load_object("december\\californian17SUBG")
CA18SUBGtime, CA18SUBGval = load_object("december\\californian18SUBG")
CA19SUBGtime, CA19SUBGval = load_object("december\\californian19SUBG")
CA20SUBGtime, CA20SUBGval = load_object("december\\californian20SUBG")
cutCASUBG = minimum([
    #length(CA01SUBGval),
    length(CA02SUBGval),
    length(CA03SUBGval),
    length(CA04SUBGval),
    length(CA05SUBGval),
    length(CA06SUBGval),
    length(CA07SUBGval),
    length(CA08SUBGval),
    length(CA13SUBGval),
    length(CA14SUBGval),
    length(CA15SUBGval),
    length(CA16SUBGval),
    length(CA17SUBGval),
    length(CA18SUBGval),
    length(CA19SUBGval),
    length(CA20SUBGval)])
selectCASUBG = argmin([
    #length(CA01SUBGval),
    length(CA02SUBGval),
    length(CA03SUBGval),
    length(CA04SUBGval),
    length(CA05SUBGval),
    length(CA06SUBGval),
    length(CA07SUBGval),
    length(CA08SUBGval),
    length(CA13SUBGval),
    length(CA14SUBGval),
    length(CA15SUBGval),
    length(CA16SUBGval),
    length(CA17SUBGval),
    length(CA18SUBGval),
    length(CA19SUBGval),
    length(CA20SUBGval)])
matrixCASUBG = [
    #CA01SUBGval[1:cutCASUBG],
    CA02SUBGval[1:cutCASUBG],
    CA03SUBGval[1:cutCASUBG],
    CA04SUBGval[1:cutCASUBG],
    CA05SUBGval[1:cutCASUBG],
    CA06SUBGval[1:cutCASUBG],
    CA07SUBGval[1:cutCASUBG],
    CA08SUBGval[1:cutCASUBG],
    CA13SUBGval[1:cutCASUBG],
    CA14SUBGval[1:cutCASUBG],
    CA15SUBGval[1:cutCASUBG],
    CA16SUBGval[1:cutCASUBG],
    CA17SUBGval[1:cutCASUBG],
    CA18SUBGval[1:cutCASUBG],
    CA19SUBGval[1:cutCASUBG],
    CA20SUBGval[1:cutCASUBG]]
aggregateCASUBG = mean(matrixCASUBG)

# %%
plot(xlabel = "Time in seconds", ylabel = "Function value gap", title = "Californian dataset", ylims = (0,300))
plot!(CA13BLMtime[2:end], aggregateCABLM, label = "BLM")
plot!(CA14BPLMtime[2:end], aggregateCABPLM, label = "BPLM", marker=:circle, markersize=1)
plot!(CA14DAtime[2:end], aggregateCADA, label = "DA")
plot!(CA14DOWGtime[2:end], aggregateCADOWG, label = "DOWG")
plot!(CA14ESTPOLtime[2:end], aggregateCAESTPOL, label = "ESTPOL")
plot!(CA14SUBGtime[2:end], aggregateCASUBG, label = "SUBG")
savefig("december\\AggregatePlotCA")

# %% [markdown]
# # PRECISION AGGREGATIONS

# %% [markdown]
# # Belgian stuff

# %%
CAinstances = []
for file in readdir("C:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\data\\ca"; join=true)
    push!(CAinstances, UT.load_data(file))
end
Opts = Float64[]
for (idx, instance) in enumerate(CAinstances)
    ObjM = UT.Matching(instance).Obj
    Optimal = maximum(load_object("C:\\Users\\Sofiane\\Desktop\\ConvexHullPricing\\tests\\UltraOptimalRunsCA.jld2")[idx][3])
    push!(Opts, ObjM - Optimal)
end

# %%
function get_precision(array, idx)
    precision = Float64[]
    for elt in array
        push!(precision, 100*(1 - (elt + 3000)/abs(Opts[idx])))
    end
    return precision
end

# %%
CA01time, CA01val = load_object("december\\californian1BLM")
CA02time, CA02val = load_object("december\\californian2BLM")
CA03time, CA03val = load_object("december\\californian3BLM")
CA04time, CA04val = load_object("december\\californian4BLM")
CA05time, CA05val = load_object("december\\californian5BLM")
CA06time, CA06val = load_object("december\\californian6BLM")
CA07time, CA07val = load_object("december\\californian7BLM")
CA08time, CA08val = load_object("december\\californian8BLM")
CA13time, CA13val = load_object("december\\californian13BLM")
CA14time, CA14val = load_object("december\\californian14BLM")
CA15time, CA15val = load_object("december\\californian15BLM")
CA16time, CA16val = load_object("december\\californian16BLM")
CA17time, CA17val = load_object("december\\californian17BLM")
CA18time, CA18val = load_object("december\\californian18BLM")
CA19time, CA19val = load_object("december\\californian19BLM")
CA20time, CA20val = load_object("december\\californian20BLM")

# %%
P01 = get_precision(CA01val[2:end], 1)
P02 = get_precision(CA02val[2:end], 2)
P03 = get_precision(CA03val[2:end], 3)
P04 = get_precision(CA04val[2:end], 4)
P05 = get_precision(CA05val[2:end], 5)
P06 = get_precision(CA06val[2:end], 6)
P07 = get_precision(CA07val[2:end], 7)
P08 = get_precision(CA08val[2:end], 8)
P13 = get_precision(CA13val[2:end], 13)
P14 = get_precision(CA14val[2:end], 14)
P15 = get_precision(CA15val[2:end], 15)
P16 = get_precision(CA16val[2:end], 16)
P17 = get_precision(CA17val[2:end], 17)
P18 = get_precision(CA18val[2:end], 18)
P19 = get_precision(CA19val[2:end], 19)
P20 = get_precision(CA20val[2:end], 20)

# %%
mean([
    CA01time[searchsortedfirst(P01, 100)],
    CA02time[searchsortedfirst(P02, 100)],
    CA03time[searchsortedfirst(P03, 100)],
    CA04time[searchsortedfirst(P04, 100)],
    CA05time[searchsortedfirst(P05, 100)],
    CA06time[searchsortedfirst(P06, 100)],
    CA07time[searchsortedfirst(P07, 100)],
    CA08time[searchsortedfirst(P08, 100)],
    CA13time[searchsortedfirst(P13, 100)],
    CA14time[searchsortedfirst(P14, 100)],
    CA15time[searchsortedfirst(P15, 100)],
    CA16time[searchsortedfirst(P16, 100)],
    #CA17time[searchsortedfirst(P17, 90)],
    CA18time[searchsortedfirst(P18, 100)],
    CA19time[searchsortedfirst(P19, 100)],
    CA20time[searchsortedfirst(P20, 100)],
    ])
# BELGIAN
# (90, 95, 98)
# BLM = [148.6, 309.5, 716.1]
# BPLM = [183.6, 454.9, 787.0]
# DA = [42.8, 369.2, 646.0]
# DOWG = [155.1, 393.3, 781.9]
# ESTPOL = [167.8, 363.8, 785.1]
# SUBG = [228.4, 345.4, 789.0]

# CALIFORNIAN
# (90, 95, 99, 100)
# BLM = [62.9, 199.7, 806.2, 897.8]
# BPLM = [56.0, 168.0, 616.2, 896.8]
# DA = [56.1, 168.3, 616.7, 897.1]
# DOWG = [56.1, 167.9, 617.1, 897.5]
# ESTPOL = [56.0, 168.1, 618.4, 897.2]
# SUBG = [56.0, 167.9, 616.8, 896.7]

# %%
plot(title = "Time to reach precision. BE dataset", xlabel = "Precision", ylabel = "Time (mn)")
scatter!([90, 95, 98], [148.6, 309.5, 716.1] ./ 60, label = "BPLM")
scatter!([90, 95, 98], [183.6, 454.9, 787.0] ./ 60, label = "DA")
scatter!([90, 95, 98], [42.8, 369.2, 646.0] ./ 60, label = "DOWG")
scatter!([90, 95, 98], [155.1, 393.3, 781.9] ./ 60, label = "BLM")
scatter!([90, 95, 98], [167.8, 363.8, 785.1] ./ 60, label = "ESTPOL")
scatter!([90, 95, 98], [228.4, 345.4, 789.0] ./ 60, label = "SUBG")
# savefig("december\\AggregatePrecisionCA")

# %%
plot(title = "Time to reach precision. Californian dataset", xlabel = "Precision", ylabel = "Time")
scatter!([90, 95, 99, 100], [56.0, 168.0, 616.2, 896.8], label = "BPLM")
scatter!([90, 95, 99, 100], [56.1, 168.3, 616.7, 897.1], label = "DA")
scatter!([90, 95, 99, 100], [56.1, 167.9, 617.1, 897.5], label = "DOWG")
scatter!([90, 95, 99, 100], [62.9, 199.7, 806.2, 897.8], label = "BLM")
scatter!([90, 95, 99, 100], [56.0, 168.1, 618.4, 897.2], label = "ESTPOL")
scatter!([90, 95, 99, 100], [56.0, 167.9, 616.8, 896.7], label = "SUBG")
savefig("december\\AggregatePrecisionCA")

# %%
searchsortedfirst(P1, 90)

# %%
@info "init acc: $(100*(1 - (BE1BLMval[1] + 3000)/abs(Opts[1])))"
@info "init acc: $(100*(1 - (BE2BLMval[1] + 3000)/abs(Opts[2])))"
@info "init acc: $(100*(1 - (BE3BLMval[1] + 3000)/abs(Opts[3])))"
@info "init acc: $(100*(1 - (BE4BLMval[1] + 3000)/abs(Opts[4])))"
@info "init acc: $(100*(1 - (BE5BLMval[1] + 3000)/abs(Opts[5])))"
@info "init acc: $(100*(1 - (BE6BLMval[1] + 3000)/abs(Opts[6])))"
@info "init acc: $(100*(1 - (BE7BLMval[1] + 3000)/abs(Opts[7])))"
@info "init acc: $(100*(1 - (BE8BLMval[1] + 3000)/abs(Opts[8])))"

# %%
@info "final acc: $(100*(1 - (minimum(BE1BLMval) + 3000)/abs(Opts[1])))"
@info "final acc: $(100*(1 - (minimum(BE2BLMval) + 3000)/abs(Opts[2])))"
@info "final acc: $(100*(1 - (minimum(BE3BLMval) + 3000)/abs(Opts[3])))"
@info "final acc: $(100*(1 - (minimum(BE4BLMval) + 3000)/abs(Opts[4])))"
@info "final acc: $(100*(1 - (minimum(BE5BLMval) + 3000)/abs(Opts[5])))"
@info "final acc: $(100*(1 - (minimum(BE6BLMval) + 3000)/abs(Opts[6])))"
@info "final acc: $(100*(1 - (minimum(BE7BLMval) + 3000)/abs(Opts[7])))"
@info "final acc: $(100*(1 - (minimum(BE8BLMval) + 3000)/abs(Opts[8])))"
#@info "BLM acc: $(100*(1 - minimum(BE2BLMval)/(Opts[2]-0)))"
